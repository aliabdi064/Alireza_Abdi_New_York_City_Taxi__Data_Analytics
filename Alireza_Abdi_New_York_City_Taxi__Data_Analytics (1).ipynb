# %% [markdown]
# **Project Title**: Predicting Taxi Fares and Tipping Behavior in New York City Using Data Analytics and Machine Learning

# %% [markdown]
# # Project Overview:

# %% [markdown]
# This project is set within a real-world scenario where Data team  partners with the New York City Taxi and Limousine Commission (NYC TLC) to derive actionable insights from their operational data. The NYC TLC oversees an extensive dataset comprising millions of rides, driver information, and related metrics, and they seek to optimise urban transportation systems using data-driven strategies.
#
# *Objective*
#
# The two main goal is to create a robust analytical foundation for NYC TLC by:
# - 1- **A regression model that helps estimate taxi fares before the ride, based on data that TLC has gathered.**
# - 2- **To build a machine learning model to predict if a customer is a generous tipper, in order to find ways to generate more revenue for taxi cab drivers.**
#
# ---
#
#
#
#
#
#
# - **Optimise Transportation Operations**
#   Help stakeholders improve route planning, driver allocation, and resource utilisation to ensure better service availability and minimise inefficiencies.
#
# - **Enhance Customer Satisfaction**
#   Identify trends and patterns in high-demand zones or peak travel times to ensure sufficient coverage, reducing wait times and improving user experiences.
#
# - **Support Policy Development**
#   Provide data-driven insights that inform policies related to pricing, fleet management, and regulations affecting taxi and limousine services.
#
# - **Prepare for Advanced Analytics**
#   Lay the groundwork for future predictive analytics and machine learning models that can forecast demand, optimise pricing strategies, and improve long-term planning.
#
# - **Promote Accountability and Transparency**
#   Use clear, evidence-based reporting to enhance stakeholder trust and align operational goals with public expectations.
#
# - **Drive Revenue Growth**
#   Analyse fare data and customer behaviour to identify potential revenue streams and cost-saving opportunities.
#
#
#
#
#
#
#
#
#
# The TLC data comes from over 200,000 taxi and limousine licensees, making approximately one million combined trips per day.
# •	It will be important to establish the relationship between any variables within the TLC data. I'd suggest the data team consider **A/B testing**, since that will analyze the relationship between the two most useful variables and subsequently provide data-driven support for future business decisions.
#
# - Cleaning and preparing raw data for analysis.
# - Identifying key variables affecting service efficiency and performance.
# - Providing preliminary insights to guide policy decisions.
# - This foundational analysis will pave the way for advanced machine learning models and predictive analytics in subsequent project phases.
#
#
# ---
#
#
# Project Phases:
#
# 1- Planning
#
# Understand NYC TLC's objectives and data context.
# Define key research questions, such as:
# - What factors contribute to peak demand periods?
# -How does driver availability impact service levels?
#
#
#
#
#
# ---
#
#
# 2- Data Acquisition and Cleaning
#
# Work with extensive ride data, focusing on aspects like pickup/drop-off locations, times, and fares.
# Use Python libraries such as Pandas and NumPy to clean and structure data for analysis.
#
#
#
# ---
#
#
# 3-Initial Analysis
#
# Conduct exploratory data analysis (EDA) to identify trends and anomalies.
# Summarise data characteristics and develop visualisations to communicate findings.
#
#
#
# ---
#
#
# 4-Deliverables
#
# Generate a detailed report for NYC TLC outlining data quality, key variables, and preliminary insights.
# Provide actionable recommendations for improving urban transport efficiency.
# Outcome
# The NYC TLC will gain a deeper understanding of their data, uncovering patterns such as high-demand areas and times, inefficiencies in route planning, and opportunities for service improvement. This analysis will serve as the basis for predictive modelling and more complex analytics in future projects.
#
# Tools and Frameworks
# - Programming Language: Python
# - Libraries: Pandas, NumPy, Matplotlib/Seaborn
# - Analytical Framework: PACE (Plan, Analyse, Communicate, Execut)
#
#
# By improving their understanding of their own data, they can identify inefficiencies, optimise service routes, and improve customer satisfaction.

# %% [markdown]
# | **Metric**               | **Definition**                                                                                                  |
# |--------------------------|----------------------------------------------------------------------------------------------------------------|
# | **VendorID**             | Identifier for the vendor providing the trip data. It indicates whether the trip was recorded by Vendor 1 or 2.|
# | **tpep_pickup_datetime** | The date and time when the trip started (Taxi and Passenger Enrichment Program, TPEP).                         |
# | **tpep_dropoff_datetime**| The date and time when the trip ended.                                                                        |
# | **passenger_count**      | The number of passengers reported by the driver or system for the trip.                                        |
# | **trip_distance**        | The total distance covered during the trip, measured in miles.                                                 |
# | **RatecodeID**           | An identifier representing the rate category applied to the trip, e.g., standard rate, airport rate, etc.      |
# | **store_and_fwd_flag**   | Indicates whether the trip record was held in the vehicle's memory before sending to the vendor (e.g., 'Y' for Yes, 'N' for No).|
# | **PULocationID**         | The unique identifier for the pickup location zone as per the TLC's zone map.                                 |
# | **DOLocationID**         | The unique identifier for the drop-off location zone as per the TLC's zone map.                               |
# | **payment_type**         | The payment method used, e.g., cash, credit card, or other methods.                                            |
# | **fare_amount**          | The base fare for the trip, calculated by the taxi meter based on the distance and time.                      |
# | **extra**                | Any additional charges applied, such as night surcharges or fees for trips during specific time periods.      |
# | **mta_tax**              | A fixed tax collected on each trip for the Metropolitan Transportation Authority (MTA).                       |
# | **tip_amount**           | The tip given to the driver by the passenger (applicable to non-cash payments).                               |
# | **tolls_amount**         | The total tolls paid during the trip, if applicable.                                                          |
# | **improvement_surcharge**| A fixed fee collected to support improvements in taxi and limousine services.                                 |
# | **total_amount**         | The total cost of the trip, including the fare, extras, taxes, tolls, tips, and surcharges.                   |

# %%
# prompt: write a code that recall my data in google drive under topic: Taxi_Trip_Data

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Replace 'your_file_path' with the actual path to your data file in Google Drive.
# Example: '/content/drive/MyDrive/Taxi_Trip_Data/taxi_data.csv'
file_path = '/content/drive/MyDrive/Taxi_Trip_Data.csv'

df = pd.read_csv(file_path)
df.rename(columns={"Unnamed: 0" : "trip_id"}, inplace=True)
print("done")
# Out:
# Mounted at /content/drive
# done

# %%
df.head(10)
# Out:
#      trip_id  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0   24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1   35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2  106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3   38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4   30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5   23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6   37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7   69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8    8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9   95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
df.describe()
# Out:
#             trip_id      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_id                22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
import pandas as pd

# Max amount for a single trip
max_distance = df['trip_distance'].max()

# Printing the result
print(f"The maximum trip distance is: {max_distance}")
# Out:
# The maximum trip distance is: 33.96

# %%
# prompt: wrtite a maximum amount for "total_amount" columb

# Maximum amount for total_amount
max_total_amount = df['total_amount'].max()

# Printing the result
print(f"The maximum total amount is: {max_total_amount}")
# Out:
# The maximum total amount is: 1200.29

# %% [markdown]
# we want to know  max amount and price price relationship. are there  the most expensive ride are not the longest ride? the answer is no

# %%
# Out:
#         trip_id  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 9280   51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 13861  40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 6064   49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 10291  76319330         2  09/11/2017 11:41:04 AM  09/11/2017 12:18:58 PM
# 29     94052446         2   11/06/2017 8:30:50 PM  11/07/2017 12:00:00 AM
# ...         ...       ...                     ...                     ...
# 2440   63574825         1  07/26/2017 10:26:58 PM  07/26/2017 10:26:58 PM
# 15916  47368116         1   06/29/2017 7:30:30 PM   06/29/2017 7:43:29 PM
# 1350   91619825         2   10/30/2017 8:20:29 AM   10/30/2017 8:20:38 AM
# 246    78660848         1   09/18/2017 8:50:53 PM   09/18/2017 8:51:03 PM
# 17788  58079289         1  07/08/2017 12:54:02 AM  07/08/2017 12:55:03 AM
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
trip_distance_sorted = df.sort_values('trip_distance', ascending=False)["trip_distance"]
# Sort the data by trip distance from maximum to minimum value

total_amount_sorted = df.sort_values("total_amount", ascending=False)["total_amount"]
total_amount_sorted.head(20)
# Sort the data by total amount and print the top 20 values
# Out:
# 8476     1200.29
# 20312     450.30
# 13861     258.21
# 12511     233.74
# 15474     211.80
# 6064      179.06
# 16379     157.06
# 3582      152.30
# 11269     151.82
# 9280      150.30
# 1928      137.80
# 10291     131.80
# 6708      126.00
# 11608     123.30
# 908       121.56
# 7281      120.96
# 18130     119.31
# 13621     115.94
# 13359     111.95
# 29        111.38
# Name: total_amount, dtype: float64

# %%
total_amount_sorted.tail(20)
# Out:
# 14283      0.31
# 19067      0.30
# 10506      0.00
# 5722       0.00
# 4402       0.00
# 22566      0.00
# 1646      -3.30
# 18565     -3.80
# 314       -3.80
# 5758      -3.80
# 5448      -4.30
# 4423      -4.30
# 10281     -4.30
# 8204      -4.80
# 20317     -4.80
# 11204     -5.30
# 14714     -5.30
# 17602     -5.80
# 20698     -5.80
# 12944   -120.30
# Name: total_amount, dtype: float64

# %% [markdown]
# By order in terms of total amount, many negative values appear.

# %%
#==> ENTER YOUR CODE HERE
df["payment_type"].value_counts()
# How many of each payment type are represented in the data?
# There are four payment types represented in the data.
# Out:
# payment_type
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: count, dtype: int64

# %% [markdown]
# According to the data dictionary, the payment method was encoded as follows:
#
# 1 = Credit card
# 2 = Cash
# 3 = No charge
# 4 = Dispute
# 5 = Unknown
# 6 = Voided trip

# %%
df.head()
# Out:
#      trip_id  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0   24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1   35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2  106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3   38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4   30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %% [markdown]
# What is the average tip for trips paid for with credit card?

# %%
avg_tip_credit = df[df['payment_type']== 1]['tip_amount'].mean()

print('AVGERAGE tip paid by credit card = ${:.2f}'.format(avg_tip_credit))
# Out:
# AVGERAGE tip paid by credit card = $2.73

# %% [markdown]
# The code computes the average tip amount for transactions where the payment_type is 1.

# %% [markdown]
# What is the average tip for trips paid for with cash?

# %%
avg_tip_cash = df[df['payment_type']== 2]['tip_amount'].mean()

print('AVGERAGE tip paid by cash = ${:.2f}'.format(avg_tip_cash))
# Out:
# AVG tip paid by cash = $0.00

# %%
#==> ENTER YOUR CODE HERE
df["VendorID"].value_counts().reset_index(name="counts")
# How many times is each vendor ID represented in the data?
#The values are representd the following:
#2    12626 time
#1    10073 times
# Out:
#    VendorID  counts
# 0         2   12626
# 1         1   10073

# %%
# What is the mean total amount for each vendor?
(df
 .groupby(["VendorID"])
 .agg({"total_amount": "mean"})
 )
# Out:
#           total_amount
# VendorID
# 1            16.298119
# 2            16.320382

# %%
#==> ENTER YOUR CODE HERE

# Filter the data for credit card payments only
(df
 .query("payment_type == 1")
)

#==> ENTER YOUR CODE HERE

# Filter the credit-card-only data for passenger count only
(df
 .query("payment_type == 1")
)["passenger_count"].value_counts()
# Out:
# passenger_count
# 1    10977
# 2     2168
# 5      775
# 3      600
# 6      451
# 4      267
# 0       27
# Name: count, dtype: int64

# %%
#==> ENTER YOUR CODE HERE

# Calculate the average tip amount for each passenger count (credit card payments only)
(df
 .query("payment_type == 1")
 .groupby(["passenger_count"])
 .agg({"tip_amount":"mean"})
)
# Out:
#                  tip_amount
# passenger_count
# 0                  2.610370
# 1                  2.714681
# 2                  2.829949
# 3                  2.726800
# 4                  2.607753
# 5                  2.762645
# 6                  2.643326

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
sns.set_theme(style="white")
# Load dataset into dataframe
df = pd.read_csv(file_path)
df.rename(columns={"Unnamed: 0" : "trip_id"}, inplace=True)
#The operation updates the DataFrame (or Series) in place.
#It saves memory and avoids creating a new object, which can be beneficial when working with large datasets.
#The method returns None, indicating that the changes were applied directly.

# %%
df.columns
# Out:
# Index(['trip_id', 'VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount'],
#       dtype='object')

# %%
df.size
# Out:
# 408582

# %% [markdown]
# Date columns to datetime in order to derive total trip duration: First, convert data columns to datetime.

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

df.head()
# Out:
#      trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# ...

# %% [markdown]
#  create a (time) duration column by using the previously converted to datetime columns tpep_pickup_datetime and tpep_dropoff_datetime.

# %%
df['duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime'])/np.timedelta64(1,'m')

df
# Out:
#          trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1       35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2      106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3       38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4       30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
# ...          ...       ...                  ...                   ...
# 22694   14873857         2  2017-02-24 17:37:23   2017-02-24 17:40:39
# 22695   66632549         2  2017-08-06 16:43:59   2017-08-06 17:24:47
# 22696   74239933         2  2017-09-04 14:54:14   2017-09-04 14:58:22
# 22697   60217333         2  2017-07-15 12:56:30   2017-07-15 13:08:26
# 22698   17208911         1  2017-03-02 13:02:49   2017-03-02 13:16:09
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %% [markdown]
# **outliers**

# %%
fig = sns.boxplot(x=df['duration'])

plt.xlabel('duration')

plt.title('Boxplot of duration')
# Out:
# Text(0.5, 1.0, 'Boxplot of duration')

# %% [markdown]
# duration has extreme outliers on the right side

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is already loaded and processed as in the provided code

plt.figure(figsize=(15, 10))  # Adjust figure size for better layout

# Subplot 1: Box plot of total_amount
plt.subplot(2, 3, 1)
box = sns.boxplot(x=df['total_amount'])
plt.xlabel('total amount [$]')
plt.title('Boxplot of total amount')

# Subplot 2: Histogram of total_amount
plt.subplot(2, 3, 2)
plt.hist(df['total_amount'], bins=range(-10, 101, 5))
plt.title('Histogram of total amount')
plt.xlabel('total amount [$]')
plt.ylabel('counts')


# Subplot 3: Box plot of tip_amount
plt.subplot(2, 3, 3)
box = sns.boxplot(x=df['tip_amount'])
plt.xlabel('tip amount [$]')
plt.title('Boxplot of tip amount')

# Subplot 4: Histogram of tip_amount
plt.subplot(2, 3, 4)
plt.hist(df['tip_amount'], bins=range(0, 21, 2))
plt.title('Histogram of tip amount')
plt.xlabel('tip amount [$]')
plt.ylabel('counts')

# Subplot 5: Histogram of tip_amount by vendor
plt.subplot(2, 3, 5)
ax = sns.histplot(data=df, x='tip_amount', bins=range(0, 21, 1),
                  hue='VendorID', multiple='stack', palette='colorblind')
ax.set_xticks(range(0, 21, 1))
ax.set_xticklabels(range(0, 21, 1))
plt.title('Tip amount by vendor histogram')

# Subplot 6: Histogram of tip_amount by vendor for tips > $10
plt.subplot(2, 3, 6)
ax = sns.histplot(data=df[df['tip_amount'] > 10], x='tip_amount', bins=range(10, 21, 1),
                  hue='VendorID', multiple='stack', palette='dark')
ax.set_xticks(range(10, 21, 1))
ax.set_xticklabels(range(10, 21, 1))
plt.title('Tip amount by vendor histogram for tips > 10$')


plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %% [markdown]
# - he majority of the trips were journeys less than two miles.The number of trips falls away steeply as the distance traveled increases beyond two miles.
# - The total cost of trip has a distribution skewed to the right, with most of the cost in the $5-15 range.
# -Vendor 2 is tipped slightly more than vendor 1.
#
# - Created histogram of tip_amount by vendor for tips > $10

# %% [markdown]
# Mean tips by passenger count

# %%
#==> ENTER YOUR CODE HERE
df["passenger_count"].value_counts()
# Out:
# passenger_count
# 1    16117
# 2     3305
# 5     1143
# 3      953
# 6      693
# 4      455
# 0       33
# Name: count, dtype: int64

# %% [markdown]
# The number of passengers of the taxi rides span the [0-6] interval. Strangely, there are registered rides with 0 passengers. They might be dropped, unless a good explanation for rides with 0 passengers is found.

# %%
print('\n Passenger counts [%] \n')
df[['passenger_count']].value_counts()/len(df)*100
# Out:
#  Passenger counts [%]
# passenger_count
# 1                  71.003128
# 2                  14.560113
# 5                   5.035464
# 3                   4.198423
# 6                   3.052998
# 4                   2.004494
# 0                   0.145381
# Name: count, dtype: float64

# %% [markdown]
# More than 70% of the taxis transport single passengers.

# %%
# Calculate mean tips by passenger_count
#==> ENTER YOUR CODE HERE
mean_tips_by_passenger_count = df.groupby(["passenger_count"]).agg({"tip_amount": "mean"}).sort_values(by="tip_amount", ascending=False)
mean_tips_by_passenger_count
# Out:
#                  tip_amount
# passenger_count
# 0                  2.135758
# 5                  1.873185
# 2                  1.856378
# 1                  1.848920
# 6                  1.720260
# 3                  1.716768
# 4                  1.530264

# %%
data = mean_tips_by_passenger_count.tail(-1)
pal = sns.color_palette("rocket",len(data))
rank = data['tip_amount'].argsort().argsort()
plt.figure(figsize=(10,6))
ax = sns.barplot(x=data.index,y=data['tip_amount'],palette=np.array(pal[::-1])[rank])
ax.axhline(df['tip_amount'].mean(),ls='--',color='blue',label='global mean')

ax.legend()

plt.xlabel('No. passengers (passenger count)')
plt.ylabel('tip amount [$]')
plt.title('Mean tip amount [$] by passenger count',fontsize=16);
# Out:
# <ipython-input-45-24e1eeb8f6c6>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=data.index,y=data['tip_amount'],palette=np.array(pal[::-1])[rank])
# <ipython-input-45-24e1eeb8f6c6>:5: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   ax = sns.barplot(x=data.index,y=data['tip_amount'],palette=np.array(pal[::-1])[rank])

# %% [markdown]
#  the mean tip is substantially the same for the six passenger categories.

# %% [markdown]
# **Fare Amount**

# %%
box = sns.boxplot(x=df['fare_amount'])
plt.xlabel('Fare amount')
plt.title('Boxplot of fare amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of fare amount')

# %% [markdown]
# **Create month and day columns**

# %%
df['month'] = df['tpep_pickup_datetime'].dt.month_name()
df['day'] = df['tpep_pickup_datetime'].dt.day_name()

df.head()
# Out:
#      trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  ...  fare_amount  extra  mta_tax  tip_amount  \
# 0           100           231  ...         13.0    0.0      0.5        2.76
# ...

# %% [markdown]
# **Total ride count and revenues by month**

# %%
rides_month = df['month'].value_counts()

rides_month
# Out:
# month
# March        2049
# October      2027
# April        2019
# May          2013
# January      1997
# June         1964
# December     1863
# November     1843
# February     1769
# September    1734
# August       1724
# July         1697
# Name: count, dtype: int64

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
         'August', 'September', 'October', 'November', 'December']

rides_month = rides_month.reindex(index=month_order)
rides_month
# Out:
# month
# January      1997
# February     1769
# March        2049
# April        2019
# May          2013
# June         1964
# July         1697
# August       1724
# September    1734
# October      2027
# November     1843
# December     1863
# Name: count, dtype: int64

# %%
#Create a bar plot of total rides per month.

plt.figure(figsize=(12,6))

sns.barplot(x=rides_month.index,y=rides_month,palette='cubehelix')

plt.title('Total rides per month')
plt.xlabel('month')
plt.ylabel('TOT rides')

plt.show()
# Out:
# <ipython-input-57-574ddeba5cfb>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_month.index,y=rides_month,palette='cubehelix')

# %%
revenues_month = df.groupby(['month'])['total_amount'].sum()

revenues_month = revenues_month.reindex(index=month_order)
revenues_month
# Out:
# month
# January      31735.25
# February     28937.89
# March        33085.89
# April        32012.54
# May          33828.58
# June         32920.52
# July         26617.64
# August       27759.56
# September    28206.38
# October      33065.83
# November     30800.44
# December     31261.57
# Name: total_amount, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(x=revenues_month.index,y=revenues_month,palette='icefire')

plt.title('Total revenues per month')
plt.xlabel('month')
plt.ylabel('TOT revenues')

plt.show()
# Out:
# <ipython-input-68-91f067b42501>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenues_month.index,y=revenues_month,palette='icefire')

# %% [markdown]
# Total ride count and revenues by day

# %%
#Total ride count
week_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

rides_day = df['day'].value_counts()

rides_day = rides_day.reindex(index=week_order)
rides_day
# Out:
# day
# Monday       2931
# Tuesday      3198
# Wednesday    3390
# Thursday     3402
# Friday       3413
# Saturday     3367
# Sunday       2998
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.barplot(x=rides_day.index,y=rides_day,palette='cubehelix')

plt.title('Total rides by day')
plt.xlabel('day')
plt.ylabel('TOT rides')

plt.show()
# Out:
# <ipython-input-62-4a76296916d4>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_day.index,y=rides_day,palette='cubehelix')

# %%
revenues_day = df.groupby(['day'])['total_amount'].sum()

revenues_day = revenues_day.reindex(index=week_order)
revenues_day
# Out:
# day
# Monday       49574.37
# Tuesday      52527.14
# Wednesday    55310.47
# Thursday     57181.91
# Friday       55818.74
# Saturday     51195.40
# Sunday       48624.06
# Name: total_amount, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(x=revenues_day.index,y=revenues_day,palette='icefire')

plt.title('Total revenues by day')
plt.xlabel('day')
plt.ylabel('TOT revenues')

plt.show()
# Out:
# <ipython-input-65-cef8bb1bf9ec>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=revenues_day.index,y=revenues_day,palette='icefire')

# %%
def date_range(df):
  """
  This function takes a Pandas DataFrame with a 'tpep_pickup_datetime' column
  and prints the first and last dates in the dataset.  It converts the column
  to datetime objects if it's not already.

  Args:
      df: The input Pandas DataFrame.
  """
  try:
    # Convert 'tpep_pickup_datetime' to datetime objects if necessary
    if not pd.api.types.is_datetime64_any_dtype(df['tpep_pickup_datetime']):
        df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

    # Get the first and last dates
    start_date = df['tpep_pickup_datetime'].min().date()
    end_date = df['tpep_pickup_datetime'].max().date()

    print(f"Start date: {start_date}")
    print(f"End date: {end_date}")

  except KeyError:
    print("Error: 'tpep_pickup_datetime' column not found in the DataFrame.")
  except Exception as e:
    print(f"An unexpected error occurred: {e}")

date_range(df)
# Out:
# Start date: 2017-01-01
# End date: 2017-12-31

# %% [markdown]
# **Plot mean trip distance by drop-off location**

# %%
# Get number of unique drop-off location IDs show different areas
df["DOLocationID"].nunique()
# Out:
# 216

# %% [markdown]
# **the mean trip distance for each drop-off location.**

# %%
mean_trip_distance = df.groupby(['DOLocationID'])[['trip_distance']].mean()

mean_trip_distance = mean_trip_distance.sort_values(by='trip_distance')
mean_trip_distance
# Out:
#               trip_distance
# DOLocationID
# 207                1.200000
# 193                1.390556
# 237                1.555494
# 234                1.727806
# 137                1.818852
# ...                     ...
# 51                17.310000
# 11                17.945000
# 210               20.500000
# 29                21.650000
# 23                24.275000
#
# [216 rows x 1 columns]

# %% [markdown]
# Create a bar plot of mean trip distances by drop-off location in ascending order by distance.

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Data for the mean trip distance
data = mean_trip_distance

# Create the barplot with a specified colour palette
# The 'palette' argument is used to change the colour of the bars
ax = sns.barplot(x=data.index, y=data["trip_distance"], order=data.index, palette='Blues')  # Change 'Blues' to your desired palette

# Remove the x-axis labels and ticks
ax.set_xticklabels([])
ax.set_xticks([])

# Set the title and labels
plt.title('Mean trip distances by drop-off location')
plt.xlabel('drop-off location ID')
plt.ylabel('trip distance', fontsize=14)

# Show the plot
plt.show()
# Out:
# <ipython-input-76-774be8eedb98>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=data.index, y=data["trip_distance"], order=data.index, palette='Blues')  # Change 'Blues' to your desired palette

# %% [markdown]
# This plot represents a characteristic curve related to the cummulative density function of a normal distribution. In order words, it indicates that the drop-off points are relatively evenly distributed over the terrain.

# %%
#Create a sample of coordinates from a normal distribution—in this case 1,500 pairs of points from a normal distribution with a mean of 10 and a standard deviation of 5
# Calculate the distance between each pair of coordinates
# Group the coordinates by endpoint and calculate the mean distance between that endpoint and all other points it was paired with
# Plot the mean distance for each unique endpoint

import numpy as np
import matplotlib.pyplot as plt

# Generate 1500 pairs of coordinates from a normal distribution
np.random.seed(42)  # for reproducibility
mean = 10
std_dev = 5
num_points = 1500

x_coords = np.random.normal(mean, std_dev, num_points)
y_coords = np.random.normal(mean, std_dev, num_points)

coordinates = list(zip(x_coords, y_coords))

# Calculate the distance between each pair of coordinates
distances = []
for i in range(num_points):
    for j in range(i + 1, num_points):
        dist = np.sqrt((coordinates[i][0] - coordinates[j][0])**2 + (coordinates[i][1] - coordinates[j][1])**2)
        distances.append((i, j, dist))

# Group the coordinates by endpoint and calculate the mean distance
endpoint_distances = {}
for i in range(num_points):
  endpoint_distances[i] = []
  for start,end,dist in distances:
    if start == i or end == i:
      if start ==i:
        endpoint_distances[i].append(dist)
      else:
        endpoint_distances[i].append(dist)

mean_distances = {}
for endpoint, dists in endpoint_distances.items():
  if dists:  # Check if the list of distances is not empty
    mean_distances[endpoint] = np.mean(dists)

# Plot the mean distance for each unique endpoint
endpoints = list(mean_distances.keys())
mean_dists = list(mean_distances.values())

plt.figure(figsize=(10, 6))
plt.scatter(endpoints, mean_dists)
plt.xlabel("Endpoint Index")
plt.ylabel("Mean Distance")
plt.title("Mean Distance to Other Endpoints")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-5b91f04810af> in <cell line: 29>()
#       1 # prompt: Create a sample of coordinates from a normal distribution—in this case 1,500 pairs of points from a normal distribution with a mean of 10 and a standard deviation of 5
#       2 # Calculate the distance between each pair of coordinates
#       3 # Group the coordinates by endpoint and calculate the mean distance between that endpoint and all other points it was paired with
#       4 # Plot the mean distance for each unique endpoint
#       5
#
# KeyboardInterrupt:

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# Note. For the purpose of this exercise, assume that the sample data comes from an experiment in which customers are randomly selected and divided into two groups: 1) customers who are required to pay with credit card, 2) customers who are required to pay with cash. Without this assumption, we cannot draw causal conclusions about how payment method affects fare amount.
#
# The goal is to apply descriptive statistics and hypothesis testing in Python. The goal for this A/B test is to sample data and analyze whether there is a relationship between payment type and fare amount. For example: discover if customers who use credit cards pay higher fare amounts than customers who use cash.

# %%
taxi_credit = df[df['payment_type'] == 1]
taxi_cash = df[df['payment_type'] == 2]

# %% [markdown]
# You are interested in the relationship between payment type and the fare amount the customer pays. One approach is to look at the average fare amount for each payment type.

# %%
taxi_credit_mean = taxi_credit['fare_amount'].mean()
taxi_cash_mean = taxi_cash['fare_amount'].mean()

print('the mean values of the credit card and cash fares are: ${:.2f} and ${:.2f}'.format(taxi_credit_mean,taxi_cash_mean))
# Out:
# the mean values of the credit card and cash fares are: $13.43 and $12.21

# %% [markdown]
# Based on the averages shown, it appears that customers who pay in credit card tend to pay a larger fare amount than customers who pay in cash. However, this difference might arise from random sampling, rather than being a true difference in fare amount. To assess whether the difference is statistically significant, you conduct a hypothesis test.

# %% [markdown]
# Hypothesis Testing
#
# - H0
#  : There is no difference in the average fare amount between customers who use credit cards and customers who use cash (null hypothesis).
# - H1
#  : There is a difference in the average fare amount between customers who use credit cards and customers who use cash (alternative hypothesis).
#
# For the purpose of this exercise, your hypothesis test is the main component of your A/B test.
# You choose 5% as the significance level and proceed with a two-sample t-test

# %%
from scipy import stats
stats.ttest_ind(a=taxi_credit['fare_amount'],b=taxi_cash['fare_amount'],equal_var=False)
# Out:
# TtestResult(statistic=6.866800855655372, pvalue=6.797387473030518e-12, df=16675.48547403633)

# %% [markdown]
# **Build a Multiple Linear Regression Model**
#
# *Now its time to work on predicting the taxi fare amounts.*

# %% [markdown]
# Outlier

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Boxplots for outlier detection')

sns.boxplot(ax=axes[0],x=df['trip_distance'])
sns.boxplot(ax=axes[1],x=df['fare_amount'])
sns.boxplot(ax=axes[2],x=df['duration'])

plt.show();

# %%
#Calculate the count of rides where the trip_distance is zero.
df[df['trip_distance'] == 0].count()
# Out:
# trip_id                  148
# VendorID                 148
# tpep_pickup_datetime     148
# tpep_dropoff_datetime    148
# passenger_count          148
# trip_distance            148
# RatecodeID               148
# store_and_fwd_flag       148
# PULocationID             148
# DOLocationID             148
# payment_type             148
# fare_amount              148
# extra                    148
# mta_tax                  148
# tip_amount               148
# tolls_amount             148
# improvement_surcharge    148
# total_amount             148
# duration                 148
# month                    148
# day                      148
# dtype: int64

# %%
df['fare_amount'].describe()
# Out:
# count    22699.000000
# mean        13.026629
# std         13.243791
# min       -120.000000
# 25%          6.500000
# 50%          9.500000
# 75%         14.500000
# max        999.990000
# Name: fare_amount, dtype: float64

# %% [markdown]
# It is reasonable to impute values less than $0 with 0.

# %%
df.loc[df.fare_amount < 0,'fare_amount'] = 0

df['fare_amount'].describe()
# Out:
# count    22699.000000
# mean        13.033832
# std         13.212462
# min          0.000000
# 25%          6.500000
# 50%          9.500000
# 75%         14.500000
# max        999.990000
# Name: fare_amount, dtype: float64

# %% [markdown]
# Now impute the maximum value as Q3 + (6 * IQR), where IQR is the differece between the first and third quartiles, Q1 and Q3

# %%
def outlier_imputation(dataframe,columns):
    '''
    Impute upper-limit values in specified columns based on their interquartile range.

    Arguments:
        column_list: A list of columns to iterate over
        iqr_factor: A number representing x in the formula:
                    Q3 + (x * IQR). Used to determine maximum threshold,
                    beyond which a point is considered an outlier.

    The IQR is computed for each column in column_list and values exceeding
    the upper threshold for each column are imputed with the upper threshold value.
    '''
    for column in columns:
        # Reassign minimum to zero
        dataframe.loc[dataframe[column] < 0, column] = 0

        # Calculate upper threshold
        Q1 = np.percentile(dataframe[column],25)
        Q3 = np.percentile(dataframe[column],75)
        IQR = Q3 - Q1
        threshold = Q3 + 6 * IQR

        # Reassign values > threshold to threshold
        dataframe.loc[dataframe[column] > threshold, column] = threshold

outlier_imputation(df,['fare_amount'])

df['fare_amount'].describe()
# Out:
# count    22699.000000
# mean        12.897913
# std         10.541137
# min          0.000000
# 25%          6.500000
# 50%          9.500000
# 75%         14.500000
# max         62.500000
# Name: fare_amount, dtype: float64

# %% [markdown]
# the interquartile range (IQR) is a measure of statistical dispersion, which is the spread of the data.
#
# the maximum value in fare_amount is 62.5 (before it was 999.99)

# %% [markdown]
#  duration outliers

# %%
df['duration'].describe()
# Out:
# count    22699.000000
# mean        17.013777
# std         61.996482
# min        -16.983333
# 25%          6.650000
# 50%         11.183333
# 75%         18.383333
# max       1439.550000
# Name: duration, dtype: float64

# %%
outlier_imputation(df,['duration'])

df['duration'].describe()
# Out:
# count    22699.000000
# mean        14.460555
# std         11.947043
# min          0.000000
# 25%          6.650000
# 50%         11.183333
# 75%         18.383333
# max         88.783333
# Name: duration, dtype: float64

# %% [markdown]
#  **Making model**

# %% [markdown]
#   - Create mean_distance column
# Create a column called mean_distance that captures the mean distance for each group of trips that share pickup and dropoff points.
#
# - Begin by creating a helper column called pickup_dropoff, which contains the unique combination of pickup and dropoff location IDs for each row.
#
#
# When deployed, the model will not know the duration of a trip until after the trip occurs, so you cannot train a model that uses this feature. However, you can use the statistics of trips you do know to generalize about ones you do not know.
#
# In this step, create a column called mean_distance that captures the mean distance for each group of trips that share pickup and dropoff points.
#
# Begin by creating a helper column called pickup_dropoff, which contains the unique combination of pickup and dropoff location IDs for each row.
#
# One way to do this is to convert the pickup and dropoff location IDs to strings and join them, separated by a space. The space is to ensure that, for example, a trip with pickup/dropoff points of 12 & 151 gets encoded differently than a trip with points 121 & 51.

# %%
df['pickup_dropoff'] = df['PULocationID'].apply(str) + ' ' + df['DOLocationID'].apply(str)

df.head()
# Out:
#      trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  ...  extra  mta_tax  tip_amount  tolls_amount  \
# 0           100           231  ...    0.0      0.5        2.76           0.0
# ...

# %% [markdown]
# Now, use a groupby() statement to group each row by the new pickup_dropoff column, compute the mean, and capture the values only in the trip_distance column. Assign the results to a variable named grouped.

# %% [markdown]
# Becase we can guess from the id location and we can mix them to undersatnd the duration and price so we have to combine somehow to calculate and making unique price base on that .
#
#
# Convert it to a dictionary using the to_dict() method. Assign the results to a variable called grouped_dict. This will result in a dictionary with a key of trip_distance whose values are another dictionary. The inner dictionary's keys are pickup/dropoff points and its values are mean distances. This is the information you want.

# %% [markdown]
# Reassign the grouped_dict dictionary so it contains only the inner dictionary. In other words, get rid of trip_distance as a key.

# %%
grouped = df.groupby('pickup_dropoff')[['trip_distance']].mean()

grouped[0:10]
# Out:
#                 trip_distance
# pickup_dropoff
# 1 1                  2.433333
# 10 148              15.700000
# 100 1               16.890000
# 100 100              0.253333
# 100 107              1.180000
# 100 113              2.024000
# 100 114              1.940000
# 100 12               4.550000
# 100 125              2.840000
# 100 13               4.201667

# %%
grouped_dict = grouped.to_dict()

# %%
grouped_dict = grouped_dict['trip_distance']

#grouped_dict

# %%
df['mean_distance'] = df['pickup_dropoff']

# %%
df['mean_distance'] = df['mean_distance'].map(grouped_dict)

df['mean_distance']
# Out:
# 0         3.521667
# 1         3.108889
# 2         0.881429
# 3         3.700000
# 4         4.435000
#            ...
# 22694     1.098214
# 22695    18.757500
# 22696     0.684242
# 22697     2.077500
# 22698     1.476970
# Name: mean_distance, Length: 22699, dtype: float64

# %% [markdown]
# Repeat the process used to create the mean_distance column to create a mean_duration column.

# %%
grouped_duration = df.groupby('pickup_dropoff')[['duration']].mean()
grouped_duration_dict = grouped_duration.to_dict()
grouped_duration_dict = grouped_duration_dict['duration']

df['mean_duration'] = df['pickup_dropoff']
df['mean_duration'] = df['mean_duration'].map(grouped_duration_dict)

# Confirm that it worked
df['mean_duration']
# Out:
# 0        22.847222
# 1        24.470370
# 2         7.250000
# 3        30.250000
# 4        14.616667
#            ...
# 22694     8.594643
# 22695    59.560417
# 22696     6.609091
# 22697    16.650000
# 22698     9.405556
# Name: mean_duration, Length: 22699, dtype: float64

# %%
df['day'] = df['tpep_pickup_datetime'].dt.day_name().str.lower()

df['month'] = df['tpep_pickup_datetime'].dt.month_name().str.lower()

df.head()
# Out:
#      trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  ...  tip_amount  tolls_amount  \
# 0           100           231  ...        2.76           0.0
# ...

# %%
# Create 'rush_hour' col
df['rush_hour'] = df['tpep_pickup_datetime'].dt.hour

# If day is Saturday or Sunday, impute 0 in `rush_hour` column
df.loc[df['day'].isin(['saturday','sunday']),'rush_hour'] = 0

df.head()
# Out:
#      trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  ...  tolls_amount  improvement_surcharge  \
# 0           100           231  ...           0.0                    0.3
# ...

# %%
# Define 'rush_hourizer' function
def rush_hourizer(hour):

    if 6 <= hour['rush_hour'] < 10:
        val = 1
    elif 16 <= hour['rush_hour'] < 20:
        val = 1
    else:
        val = 0

    return val

# Apply the `rush_hourizer()` function to the new column
df.loc[(df.day!='saturday') & (df.day!='sunday'),'rush_hour'] = df.apply(rush_hourizer,axis=1)
df.head()
# Out:
# <ipython-input-117-1e5af043a944>:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0 1 1 ... 1 0 0]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[(df.day!='saturday') & (df.day!='sunday'),'rush_hour'] = df.apply(rush_hourizer,axis=1)
#      trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4   30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# ...

# %% [markdown]
# **mean_duration vs fare_amount**

# %%
sns.regplot(x=df['mean_duration'], y=df['fare_amount'],
            scatter_kws={'alpha':0.5, 's':5},
            line_kws={'color':'red'})

plt.title('fare_amount vs mean_duration')

plt.show()

# %%
df[df['fare_amount'] > 50]['fare_amount'].value_counts().head()
# Out:
# fare_amount
# 52.0    514
# 62.5     84
# 59.0      9
# 50.5      9
# 57.5      8
# Name: count, dtype: int64

# %%
# Set pandas to display all columns
pd.set_option('display.max_columns', None)
df[df['fare_amount']==52].head(30)
# Out:
#         trip_id  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 11     18600059         2  2017-03-05 19:15:30   2017-03-05 19:52:18
# 110    47959795         1  2017-06-03 14:24:57   2017-06-03 15:31:48
# 161    95729204         2  2017-11-11 20:16:16   2017-11-11 20:17:14
# 247   103404868         2  2017-12-06 23:37:08   2017-12-07 00:06:19
# 379    80479432         2  2017-09-24 23:45:45   2017-09-25 00:15:14
# 388    16226157         1  2017-02-28 18:30:05   2017-02-28 19:09:55
# 406    55253442         2  2017-06-05 12:51:58   2017-06-05 13:07:35
# 449    65900029         2  2017-08-03 22:47:14   2017-08-03 23:32:41
# 468    80904240         2  2017-09-26 13:48:26   2017-09-26 14:31:17
# 520    33706214         2  2017-04-23 21:34:48   2017-04-23 22:46:23
# 569    99259872         2  2017-11-22 21:31:32   2017-11-22 22:00:25
# 572    61050418         2  2017-07-18 13:29:06   2017-07-18 13:29:19
# 586    54444647         2  2017-06-26 13:39:12   2017-06-26 14:34:54
# ...

# %% [markdown]
# By examining the pickup_dropoff column, one can notice that those trips either start or end at location 132. Thus, it is likely that their starting or ending location is a place with fixed fare, like an airport.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_id                22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df2 = df.copy()

df2 = df2.drop(['trip_id', 'tpep_dropoff_datetime', 'tpep_pickup_datetime',
               'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
               'payment_type', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
               'total_amount', 'tpep_dropoff_datetime', 'tpep_pickup_datetime', 'duration',
               'pickup_dropoff', 'day', 'month'
               ], axis=1)

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VendorID         22699 non-null  int64
#  1   passenger_count  22699 non-null  int64
#  2   fare_amount      22699 non-null  float64
#  3   mean_distance    22699 non-null  float64
#  4   mean_duration    22699 non-null  float64
#  5   rush_hour        22699 non-null  int64
# dtypes: float64(3), int64(3)
# memory usage: 1.0 MB

# %%
sns.pairplot(df2[['fare_amount', 'mean_duration', 'mean_distance']],
             plot_kws={'alpha':0.4, 'size':5})

# %%
# Create correlation matrix containing pairwise correlation of columns, using pearson correlation coefficient
df2.corr(method='pearson')
# Out:
#                  VendorID  passenger_count  fare_amount  mean_distance  \
# VendorID         1.000000         0.266463     0.001045       0.004741
# passenger_count  0.266463         1.000000     0.014942       0.013428
# fare_amount      0.001045         0.014942     1.000000       0.910185
# mean_distance    0.004741         0.013428     0.910185       1.000000
# mean_duration    0.001876         0.015852     0.859105       0.874864
# rush_hour       -0.002874        -0.022035    -0.020075      -0.039725
#
#                  mean_duration  rush_hour
# VendorID              0.001876  -0.002874
# passenger_count       0.015852  -0.022035
# fare_amount           0.859105  -0.020075
# mean_distance         0.874864  -0.039725
# mean_duration         1.000000  -0.021583
# rush_hour            -0.021583   1.000000

# %%
# Create correlation heatmap

plt.figure(figsize=(6,4))
sns.heatmap(df2.corr(method='pearson'), annot=True, cmap='Reds')
plt.title('Correlation heatmap',
          fontsize=18)
plt.show()

# %% [markdown]
# Exemplar response: mean_duration and mean_distance are both highly correlated with the target variable of fare_amount They're also both correlated with each other, with a Pearson correlation of 0.87.
# Highly correlated predictor variables can be bad for linear regression models. However, correlated predictor variables can still be used to create an accurate predictor if the prediction itself is more important than using the model as a tool to learn about your data.
#
# This model will predict fare_amount, which will be used as a predictor variable in machine learning models. Therefore, try modeling with both variables even though they are correlated.

# %% [markdown]
# **Building the regression model**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

from datetime import datetime
from datetime import date
from datetime import timedelta

import sklearn.metrics as metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV,train_test_split
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error,accuracy_score,precision_score, \
    recall_score,f1_score,confusion_matrix,ConfusionMatrixDisplay,RocCurveDisplay,roc_auc_score, roc_curve
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier,plot_importance

from warnings import simplefilter
simplefilter("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
X = df2.drop(columns=['fare_amount'])

y = df2[['fare_amount']]
#Then, encode the categorical variables.

X['VendorID'] = X['VendorID'].astype(str)

X = pd.get_dummies(X,drop_first=True)
X.head()
# Out:
#    passenger_count  mean_distance  mean_duration  rush_hour  VendorID_2
# 0                6       3.521667      22.847222          0        True
# 1                1       3.108889      24.470370          0       False
# 2                1       0.881429       7.250000          1       False
# 3                1       3.700000      30.250000          0        True
# 4                1       4.435000      14.616667          0        True

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# Use StandardScaler(), fit(), and transform() to standardize the X_train variables. Assign the results to a variable called X_train_scaled.

# %%
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
print('X_train scaled:',X_train_scaled)
# Out:
# X_train scaled: [[-0.50301524  0.8694684   0.17616665 -0.64893329  0.89286563]
#  [-0.50301524 -0.60011281 -0.69829589  1.54099045  0.89286563]
#  [ 0.27331093 -0.47829156 -0.57301906 -0.64893329 -1.11998936]
#  ...
#  [-0.50301524 -0.45121122 -0.6788917  -0.64893329 -1.11998936]
#  [-0.50301524 -0.58944763 -0.85743597  1.54099045 -1.11998936]
#  [ 1.82596329  0.83673851  1.13212101 -0.64893329  0.89286563]]

# %% [markdown]
# **Fit the model to train data.**

# %%
lr = LinearRegression()
lr.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluate the model performance on train data by calculating the residual sum of squares and the explained variance score (R^2). Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error.

# %%
r_sq = lr.score(X_train_scaled, y_train)
print('Coefficient of determination:', r_sq)
y_pred_train = lr.predict(X_train_scaled)
print('R^2:', r2_score(y_train, y_pred_train))
print('MAE:', mean_absolute_error(y_train, y_pred_train))
print('MSE:', mean_squared_error(y_train, y_pred_train))
print('RMSE:',np.sqrt(mean_squared_error(y_train, y_pred_train)))
# Out:
# Coefficient of determination: 0.8398434585044773
# R^2: 0.8398434585044773
# MAE: 2.186666416775414
# MSE: 17.88973296349268
# RMSE: 4.229625629236313

# %%
X_test_scaled = scaler.transform(X_test)

r_sq_test = lr.score(X_test_scaled,y_test)
print('Coefficient of determination:',r_sq_test)
y_pred_test = lr.predict(X_test_scaled)
print('R^2:',r2_score(y_test,y_pred_test))
print('MAE:',mean_absolute_error(y_test,y_pred_test))
print('MSE:',mean_squared_error(y_test,y_pred_test))
print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred_test)))
# Out:
# Coefficient of determination: 0.8682583641795454
# R^2: 0.8682583641795454
# MAE: 2.1336549840593864
# MSE: 14.326454156998942
# RMSE: 3.7850302716093225

# %% [markdown]
# The model performance is high on both training and test sets, suggesting that there is little bias in the model and that the model is not overfit.

# %%
# Create a `results` dataframe
results = pd.DataFrame(data={'actual': y_test['fare_amount'],
                             'predicted': y_pred_test.ravel()})
results['residual'] = results['actual'] - results['predicted']
results.head()
# Out:
#        actual  predicted   residual
# 5818     14.0  12.356503   1.643497
# 18134    28.0  16.314595  11.685405
# 4655      5.5   6.726789  -1.226789
# 7378     15.5  16.227206  -0.727206
# 13914     9.5  10.536408  -1.036408

# %%
# Create a scatterplot to visualize `predicted` over `actual`
fig, ax = plt.subplots(figsize=(6, 6))
sns.set(style='whitegrid')
sns.scatterplot(x='actual',
                y='predicted',
                data=results,
                s=20,
                alpha=0.5,
                ax=ax
)
# Draw an x=y line to show what the results would be if the model were perfect
plt.plot([0,60], [0,60], c='red', linewidth=2)
plt.title('Actual vs. predicted');

# %%
# Visualize the distribution of the `residuals`
sns.histplot(results['residual'], bins=np.arange(-15,15.5,0.5))
plt.title('Distribution of the residuals')
plt.xlabel('residual value')
plt.ylabel('count');

# %%
results['residual'].mean()
# Out:
# -0.01544262152868054

# %% [markdown]
# The distribution of the residuals is approximately normal and has a mean of -0.015. A normal distribution around zero is good, as it demonstrates that the model's errors are evenly distributed and unbiased.
#
# Create a scatterplot of residuals over predicted.

# %%
sns.scatterplot(x='predicted', y='residual', data=results)
plt.axhline(0, c='red')
plt.title('Scatterplot of residuals over predicted values')
plt.xlabel('predicted value')
plt.ylabel('residual value')
plt.show()

# %% [markdown]
# The model's residuals are evenly distributed above and below zero, with the exception of the sloping lines from the upper-left corner to the lower-right corner, which you know are the imputed maximum of
# $
# 62.50
#   and the flat rate of
# $
# 52
#   for JFK airport trips.

# %%
# Get model coefficients
coefficients = pd.DataFrame(lr.coef_,columns=X.columns)
coefficients
# Out:
#    passenger_count  mean_distance  mean_duration  rush_hour  VendorID_2
# 0         0.030825       7.133867       2.812115   0.110233   -0.054373

# %% [markdown]
# Conlcusion: **The coefficients reveal that mean_distance was the feature with the greatest weight in the model's final prediction. For every mile traveled, the fare amount increases by a mean of $7. Note, however, that because some highly correlated features were not removed, the confidence interval of this assessment is wider.**

# %% [markdown]
# - VendorID (-0.031485): A unit increase in VendorID is associated with a decrease in the trip fare by approximately $0.03, holding other variables constant. This variable might not have a significant effect given its small magnitude.
#
# - Passenger Count (0.014927): For every additional passenger, the trip fare increases on average by $0.015, holding other variables constant.
#
# - Mean Distance (7.134742): For every additional mile traveled, the trip fare increases on average by $7.13. This is the feature with the greatest impact on the fare, as its coefficient has the largest magnitude.
#
# - Mean Duration (2.803586): For every additional minute of trip duration, the trip fare increases on average by $2.80, holding other factors constant.
#
# - Rush Hour (0.136533): If the trip occurs during rush hour, the fare increases on average by $0.14, compared to non-rush hour periods.

# %% [markdown]
# # Build a machine learning model

# %% [markdown]
# What are the ethical implications of the model? What are the consequences of your model making errors?
# What is the likely effect of the model when it predicts a false negative (i.e., when the model says a customer will give a tip, but they actually won't)?
# This will likely reduce the satisfaction of taxi drivers.
#
# What is the likely effect of the model when it predicts a false positive (i.e., when the model says a customer will not give a tip, but they actually will)?
# This will likely increase the chances of some circumstances, for example the drivers refusing to pick up a customer who predicts not to give a tip, it will be even worse if this customer tends to give a tip. It will likely reduce the satisfaction of customers.
#
# Do the benefits of such a model outweigh the potential problems?
# Even though this model is to generate more revenue for taxi cab drivers, it is likely to increase the chance of circumstance between the drivers and the customers. Tip_amount should not be the only one, and should not be the one to decide whether a driver is satisfied or not. Customer shouldn't be excluded even though the client represents to the driver.
#
# Would you proceed with the request to build this model? Why or why not?
# I will give my suggestion of the risk about proceeding with this request with the team.
#
# Can the objective be modified to make it less problematic?
# If we can modify the objective, we can focus on what else features that will impact drivers satisfactions. Tip_amount can be a feature that predicts if drivers are satisfied, instead of the target variable.
#
# Suppose you were to modify the modeling objective so, instead of predicting people who won't tip at all, you predicted people who are particularly generous—those who will tip 20% or more? Consider the following questions:
#
# What features do you need to make this prediction?
#
# What would be the target variable?
#
# What metric should you use to evaluate your model? Do you have enough information to decide this now?
#
# ENTER YOUR RESPONSES TO QUESTIONS 1-3 HERE:
# What features do you need to make this prediction?
# For now, we will use the as much as the features that are provided in the dataset, as long as they are not highly correlated to each other or obvious unuseful features. Because without the examine, we don't know which feature is more important.
#
# What would be the target variable?
# If we predict people who will tip 20% or more, we will need to create a binary variable that contains 1 for the tip 20% or more, 0 for the tip less than 20%. It will be the target variable.
#
# What metric should you use to evaluate your model? Do you have enough information to decide this now?
# We will use all of 4 matrics - precision, f1, recall, accuracy. But f1 can be the most useful one as it combines the information from precision and recall.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance
import pickle
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay

import matplotlib.pyplot as plt
import seaborn as sns

import warnings

warnings.filterwarnings("ignore")

# %%
import os
# RUN THE CELL BELOW TO IMPORT YOUR DATA.

#==> Read in data

df0 = pd.read_csv('/content/drive/MyDrive/Taxi_Trip_Data.csv')
df0.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %% [markdown]
# **Feature engineering**

# %%
#==> ENTER YOUR CODE HERE
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df0[df0['payment_type'] != 1]['tip_amount'].describe()
# Out:
# count    7434.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: tip_amount, dtype: float64

# %%
#==> ENTER YOUR CODE HERE
df = df0.copy()
df1 = df[df['payment_type'] == 1]

# %% [markdown]
# Target
# Notice that there isn't a column that indicates tip percent, which is what you need to create the target variable. You'll have to engineer it.
#
# Add a tip_percent column to the dataframe by performing the following calculation:
#
#
# $$
# \text{tip percent} = \frac{\text{tip amount}}{\text{total amount} - \text{tip amount}}
# $$

# %%
#==> ENTER YOUR CODE HERE
df1['tip_percent'] = (df1['tip_amount']/(df1['total_amount'] - df1['tip_amount']) )

# %% [markdown]
# Now create another column called generous. This will be the target variable. The column should be a binary indicator of whether or not a customer tipped ≥ 20% (0=no, 1=yes).
#
# - Begin by making the generous column a copy of the tip_percent column.
# - Reassign the column by converting it to Boolean (True/False).
# - Reassign the column by converting Boolean to binary (1/0).

# %%
#==> ENTER YOUR CODE HERE
df1['generous'] = df1['tip_percent']
df1['generous'] = (df1['generous'] >= 0.2)
df1['generous'] = df1['generous'].astype(int)

# %% [markdown]
# Which columns are obviously unpredictive of tip percentage? Refer to the data dictionary.
#
# Drop Unnamed: 0 and store_and_fwd_flag columns. Assign the result back to df1

# %%
#==> ENTER YOUR CODE HERE
df1 = df1.drop(['Unnamed: 0', 'store_and_fwd_flag'], axis=1)

# %% [markdown]
# Next, you're going to be working with the pickup and dropoff columns. To do this, you'll need to import the datetime module. Import this module as dt.
#
# Then, convert the tpep_pickup_datetime and tpep_dropoff_datetime columns to the datetime class.

# %%
#==> ENTER YOUR CODE HERE
df1['tpep_pickup_datetime'] = pd.to_datetime(df1['tpep_pickup_datetime'], format="%m/%d/%Y %I:%M:%S %p")
df1['tpep_dropoff_datetime'] = pd.to_datetime(df1['tpep_dropoff_datetime'], format="%m/%d/%Y %I:%M:%S %p")
df1.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# tip_percent                     float64
# generous                          int64
# dtype: object

# %% [markdown]
# Create a new column called duration, which captures the time elapsed from pickup to dropoff.
#
# Subtract tpep_pickup_datetime from tpep_dropoff_datetime and assign the result to a new column called duration.
# Convert the duration column to seconds

# %%
#==> ENTER YOUR CODE HERE
from datetime import datetime
from datetime import date
from datetime import timedelta


df1['duration'] = (df1['tpep_dropoff_datetime'] - df1['tpep_pickup_datetime'])/np.timedelta64(1,"s")
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2017-03-25 08:55:43   2017-03-25 09:09:47                6
# 1         1  2017-04-11 14:53:28   2017-04-11 15:19:58                1
# 2         1  2017-12-15 07:26:56   2017-12-15 07:34:08                1
# 3         2  2017-05-07 13:17:59   2017-05-07 13:48:14                1
# 5         2  2017-03-25 20:34:11   2017-03-25 20:42:11                6
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0           3.34           1           100           231             1
# 1           1.80           1           186            43             1
# 2           1.00           1           262           236             1
# 3           3.70           1           188            97             1
# 5           2.30           1           161           236             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# Create a day column that contains only the day of the week when each passenger was picked up. Then, convert the values to lowercase.

# %%
#==> ENTER YOUR CODE HERE
df1['day'] = df1['tpep_pickup_datetime'].dt.strftime("%A").str.lower()
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2017-03-25 08:55:43   2017-03-25 09:09:47                6
# 1         1  2017-04-11 14:53:28   2017-04-11 15:19:58                1
# 2         1  2017-12-15 07:26:56   2017-12-15 07:34:08                1
# 3         2  2017-05-07 13:17:59   2017-05-07 13:48:14                1
# 5         2  2017-03-25 20:34:11   2017-03-25 20:42:11                6
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 0           3.34           1           100           231             1
# 1           1.80           1           186            43             1
# 2           1.00           1           262           236             1
# 3           3.70           1           188            97             1
# 5           2.30           1           161           236             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# Next, engineer four new columns that represent time of day bins. Each column should contain binary values (0=no, 1=yes) that indicate whether a trip began (picked up) during the following times:
#
# am_rush = [06:00–10:00)
# daytime = [10:00–16:00)
# pm_rush = [16:00–20:00)
# nighttime = [20:00–06:00)
#
# To do this, first create the four columns. For now, each new column should contain the same information: the hour (only) from the tpep_pickup_datetime column.

# %%
#==> ENTER YOUR CODE HERE
df1['am_rush'] = df1['tpep_pickup_datetime'].dt.hour
df1['daytime'] = df1['tpep_pickup_datetime'].dt.hour
df1['pm_rush'] = df1['tpep_pickup_datetime'].dt.hour
df1['nighttime'] = df1['tpep_pickup_datetime'].dt.hour

# %% [markdown]
# You'll need to write four functions to convert each new column to binary (0/1). Begin with am_rush. Complete the function so if the hour is between [06:00–10:00), it returns 1, otherwise, it returns 0.

# %%
# Define 'am_rush()' conversion function [06:00–10:00)
def am_rush(hour):
    #==> ENTER YOUR CODE HERE
    if 6 <= hour['am_rush'] < 10:
        amrush = 1
    else:
        amrush = 0

    return amrush

# %% [markdown]
# Now, apply the am_rush() function to the am_rush series to perform the conversion. Print the first five values of the column to make sure it did what you expected it to do.
#
# Note: Be careful! If you run this cell twice, the function will be reapplied and the values will all be changed to 0.

# %%
#==> ENTER YOUR CODE HERE
df1['am_rush'] = df1.apply(am_rush, axis=1)
df1['am_rush'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 5    0
# Name: am_rush, dtype: int64

# %% [markdown]
# Write functions to convert the three remaining columns and apply them to their respective series.

# %%
# Define 'daytime()' conversion function [10:00–16:00)
def daytime(hour):
  #==> ENTER YOUR CODE HERE
    if 10 <= hour['daytime'] < 16:
        dtime = 1
    else:
        dtime = 0
    return dtime
# Apply 'daytime()' function to the 'daytime' series
#==> ENTER YOUR CODE HERE
df1['daytime'] = df1.apply(daytime, axis=1)
df1['daytime'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 5    0
# Name: daytime, dtype: int64

# %%
# Define 'pm_rush()' conversion function [16:00–20:00)
def pm_rush(hour):
  #==> ENTER YOUR CODE HERE
    if 16 <= hour['pm_rush'] < 20:
        pmrush = 1
    else:
        pmrush = 0
    return pmrush
# Apply 'pm_rush()' function to the 'pm_rush' series
#==> ENTER YOUR CODE HERE
df1['pm_rush'] = df1.apply(pm_rush, axis=1)
df1['pm_rush'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 5    0
# Name: pm_rush, dtype: int64

# %%
# Define 'nighttime()' conversion function [20:00–06:00)
def nighttime(hour):
 #==> ENTER YOUR CODE HERE
    if 20 <= hour['nighttime'] <= 24:
        ntime = 1
    elif 0 <= hour['nighttime'] < 6:
        ntime = 1
    else:
        ntime = 0
    return ntime
# Apply 'nighttime' function to the 'nighttime' series
#==> ENTER YOUR CODE HERE

df1['nighttime'] = df1.apply(nighttime, axis=1)
df1['nighttime'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 5    1
# Name: nighttime, dtype: int64

# %% [markdown]
# Now, create a month column that contains only the abbreviated name of the month when each passenger was picked up, then convert the result to lowercase.

# %%
#==> ENTER YOUR CODE HERE

df1['month'] = df1['tpep_pickup_datetime'].dt.strftime("%b").str.lower()

# %% [markdown]
# Because you have encoded much of the information contained in the pickup and dropoff columns into new columns, you can drop them for modeling.
#
# Drop the tpep_pickup_datetime and tpep_dropoff_datetime columns and reassign the result back to df1

# %%
#==> ENTER YOUR CODE HERE
df1 = df1.drop(['tpep_pickup_datetime', 'tpep_dropoff_datetime'], axis = 1)

# %%
#==> ENTER YOUR CODE HERE
df1.head()
# Out:
#    VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0         2                6           3.34           1           100
# 1         1                1           1.80           1           186
# 2         1                1           1.00           1           262
# 3         2                1           3.70           1           188
# 5         2                6           2.30           1           161
#
#    DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0           231             1         13.0    0.0      0.5        2.76
# 1            43             1         16.0    0.0      0.5        4.00
# 2           236             1          6.5    0.0      0.5        1.45
# 3            97             1         20.5    0.0      0.5        6.39
# 5           236             1          9.0    0.5      0.5        2.06
#
#    tolls_amount  improvement_surcharge  total_amount  tip_percent  generous  \
# ...

# %% [markdown]
# Many of the columns are categorical and will need to be dummied (converted to binary). Some of these columns are numeric, but they actually encode categorical information, such as RatecodeID and the pickup and dropoff locations. To make these columns recognizable to the get_dummies() function as categorical variables, you'll first need to convert them to type(str).
#
# Define a variable called cols_to_str, which is a list of the numeric columns that contain categorical information and must be converted to string: RatecodeID, PULocationID, DOLocationID.
# Write a for loop that converts each column in cols_to_string to string

# %%
#==> ENTER YOUR CODE HERE
df1[[ 'RatecodeID', 'PULocationID', 'DOLocationID']] = df1[['RatecodeID', 'PULocationID', 'DOLocationID']].astype(str)

# %% [markdown]
# The VendorID column is also a numerical column that contains categorical information (which taxi cab company picked up the passenger). The values are all 1 or 2.
#
# Convert this to binary by subtracting 1 from every value in the column.

# %%
#==> ENTER YOUR CODE HERE
df1['VendorID'] = df1['VendorID'] - 1

# %%
#==> ENTER YOUR CODE HERE
df2 = pd.get_dummies(df1)

# %% [markdown]
# Finally, drop the columns that are constant or that contain information that would be a proxy for our target variable. For example, total_amount contains tip amount, and therefore tip percentage, if used with fare_amount. And mta_tax is $0.50 99.6% of the time, so it's not adding any predictive signal to the model.
#
# Drop the following features: payment_type, mta_tax, tip_amount, total_amount, and tip_percent. Assign the results to a new dataframe called df3.

# %%
#==> ENTER YOUR CODE HERE
df3 = df2.drop(['payment_type', 'mta_tax', 'tip_amount', 'total_amount', 'tip_percent'], axis = 1)

# %% [markdown]
# Evaluation metric
# Before modeling, you must decide on an evaluation metric.
#
# Examine the class balance of your target variable.

# %%
#==> ENTER YOUR CODE HERE
df3['generous'].value_counts()
# Out:
# generous
# 0    9944
# 1    5321
# Name: count, dtype: int64

# %% [markdown]
# Approximately 1/3 of the customers in this dataset were "generous" (tipped ≥ 20%). The dataset is imbalanced, but not extremely so.
#
# To determine a metric, consider the cost of both kinds of model error:
#
# False positives (the model predicts a tip ≥ 20%, but the customer does not give one)
# False negatives (the model predicts a tip < 20%, but the customer gives more)
# False positives are worse for cab drivers, because they would pick up a customer expecting a good tip and then not receiving one.
#
# False negatives are worse for customers, because a cab driver would likely pick up a different customer who was predicted to tip more.
#
# Since your client represents taxi drivers, use a metric that evaluates false positives. Which metric is this?
#
# F1 scores are usually more useful than accuracy scores. If we care more about the false positives, it’s better to use the F1 score that combines the information from precision and recall.

# %% [markdown]
# Split the data
# Now you're ready to model. The only remaining step is to split the data into features/target variable and training/testing data.
#
# Define a variable y that isolates the target variable (generous).
# Define a variable X that isolates the features.
# Split the data into training and testing sets. Put 20% of the samples into the test set, stratify the data, and set the random state

# %%
#==> ENTER YOUR CODE HERE
y = df3['generous']
X = df3.drop(['generous'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 42)

# %% [markdown]
# Random forest¶
# Begin with using GridSearchCV to tune a random forest model.
#
# Instantiate the random forest classifier rf and set the random state.
#
# Create a dictionary cv_params of any of the following hyperparameters and their corresponding values to tune. The more you tune, the better your model will fit the data, but the longer it will take.
#
# max_depth
# max_features
# max_samples
# min_samples_leaf
# min_samples_split
# n_estimators
# Define a dictionary scoring of scoring metrics for GridSearch to capture (precision, recall, F1 score, and accuracy).
#
# Instantiate the GridSearchCV object rf_cv1. Pass to it as arguments:
#
# estimator=rf
# param_grid=cv_params
# scoring=scoring
# cv: define the number of you cross-validation folds you want (cv=_)
# refit: indicate which evaluation metric you want to use to select the model (refit=_)

# %%
#==> ENTER YOUR CODE HERE

rf = RandomForestClassifier(random_state=0)

cv_params = {'max_depth': [2,3,4,5, None],
             'min_samples_leaf': [1,2,3],
             'min_samples_split': [2,3,4],
             'max_features': [2,3,4],
             'n_estimators': [75, 100, 125, 150]
             }

scoring = ['accuracy', 'precision', 'recall', 'f1']

rf_cv1 = GridSearchCV(rf, cv_params, scoring=scoring, cv=5, refit='precision')

# %%
# %%time
#==> ENTER YOUR CODE HERE
rf_cv1.fit(X_train, y_train)
# Out:
# CPU times: user 28min 44s, sys: 19.3 s, total: 29min 4s
# Wall time: 29min 21s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0),
#              param_grid={'max_depth': [2, 3, 4, 5, None],
#                          'max_features': [2, 3, 4],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [75, 100, 125, 150]},
#              refit='precision',
#              scoring=['accuracy', 'precision', 'recall', 'f1'])

# %% [markdown]
# Now fit the model to the training data.
#
# Note: The following operation may take over an hour to complete. Therefore, the cell has been commented out along with code cell #33 (where we pickle the model). To save time, you can skip these cells and continue to execute the cells in order.

# %%
import pickle

# Define a path to the folder where you want to save the model
path = '../'
def write_pickle(path, model_object, save_name:str):
    '''
    save_name is a string.
    '''
    with open(path + save_name + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)
def read_pickle(path, saved_model_name:str):
    '''
    saved_model_name is a string.
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

        return model

# %%
rf_cv1.best_score_
# Out:
# 0.6047448523485424

# %%
rf_cv1.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 4,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'n_estimators': 150}

# %%
def make_results(model_name:str, model_object, metric:str):
  '''
  Arguments:
    model_name (string): what you want the model to be called in the output table
    model_object: a fit GridSearchCV object
    metric (string): precision, recall, f1, or accuracy

  Returns a pandas df with the F1, recall, precision, and accuracy scores
  for the model with the best mean 'metric' score across all validation folds.
  '''

  # Create dictionary that maps input metric to actual metric name in GridSearchCV
  metric_dict = {'precision': 'mean_test_precision',
                 'recall': 'mean_test_recall',
                 'f1': 'mean_test_f1',
                 'accuracy': 'mean_test_accuracy',
                 }

  # Get all the results from the CV and put them in a df
  cv_results = pd.DataFrame(model_object.cv_results_)

  # Isolate the row of the df with the max(metric) score
  best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

  # Extract Accuracy, precision, recall, and f1 score from that row
  f1 = best_estimator_results.mean_test_f1
  recall = best_estimator_results.mean_test_recall
  precision = best_estimator_results.mean_test_precision
  accuracy = best_estimator_results.mean_test_accuracy

  # Create table of results
  table = pd.DataFrame()
  table = table.append({'Model': model_name,
                        'Precision': precision,
                        'Recall': recall,
                        'F1': f1,
                        'Accuracy': accuracy,
                        },
                        ignore_index=True
                       )

  return table

# %%
results_df = make_results('Random Forest CV', rf_cv1, 'precision', X_test, y_test)
print(results_df)
# Out:
#               model     metric     value
# 0  Random Forest CV  precision  0.606164

# %%
#==> ENTER YOUR CODE HERE
rf = RandomForestClassifier(random_state=0)

cv_params = {'max_depth': [5, 6, 7],
             'max_features': [1.0],
             'max_samples': [0.7],
             'min_samples_leaf': [1,2],
             'min_samples_split': [2,3],
             'n_estimators': [300],
             }

scoring = ['accuracy', 'precision', 'recall', 'f1']

rf_cv2 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='f1')

# %%
# %%time
#==> ENTER YOUR CODE HERE

rf_cv2.fit(X_train, y_train)
# Out:
# CPU times: user 12min 58s, sys: 1.05 s, total: 12min 59s
# Wall time: 13min 5s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(random_state=0),
#              param_grid={'max_depth': [5, 6, 7], 'max_features': [1.0],
#                          'max_samples': [0.7], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3], 'n_estimators': [300]},
#              refit='f1', scoring=['accuracy', 'precision', 'recall', 'f1'])

# %%
rf_cv2.best_score_
# Out:
# 0.437992697635874

# %%
#==> ENTER YOUR CODE HERE
rf_cv2.best_params_
# Out:
# {'max_depth': 7,
#  'max_features': 1.0,
#  'max_samples': 0.7,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
def make_results(model_name: str, model_object: object) -> pd.DataFrame:
    """
    Takes in a model name and trained model object.
    Returns a pandas DataFrame with Precision, Recall, F1, and Accuracy.
    """

    predictions = model_object.predict(X_test)  # Get model predictions

    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    f1 = f1_score(y_test, predictions)

    # Create and return results DataFrame
    results_df = pd.DataFrame(data=[[model_name, precision, recall, f1, accuracy]],
                                 columns=['Model', 'Precision', 'Recall', 'F1', 'Accuracy'])
    return results_df

# %%
results_df = make_results('Random Forest F1', rf_cv2)
print(results_df)
# Out:
#               Model  Precision    Recall        F1  Accuracy
# 0  Random Forest F1   0.708333  0.335526  0.455357  0.720275

# %% [markdown]
# There was a modest improvement in both F1 and recall scores, but these results still are not good enough to deploy the model.
#
# Use your model to predict on the test data. Assign the results to a variable called preds.
#
# HINT
# Note: For this project, you will use several models to predict on the test data. Remember that this decision comes with a trade-off. What is the benefit of this? What is the drawback?

# %%
#==> ENTER YOUR CODE HERE
preds = rf_cv2.predict(X_test)

# %%
def get_test_scores(model_name:str, preds, y_test_data):
    '''
    Generate a table of test scores.

    In:
        model_name (string): Your choice: how the model will be named in the output table
        preds: numpy array of test predictions
        y_test_data: numpy array of y_test data

    Out:
        table: a pandas df of precision, recall, f1, and accuracy scores for your model
    '''
    accuracy = round(accuracy_score(y_test_data, preds), 3)
    precision = round(precision_score(y_test_data, preds), 3)
    recall = round(recall_score(y_test_data, preds), 3)
    f1 = round(f1_score(y_test_data, preds), 3)

    table = pd.DataFrame({'model': [model_name],
                        'precision': [precision],
                        'recall': [recall],
                        'f1': [f1],
                        'accuracy': [accuracy]
                        })

    return table

# %% [markdown]
# Use the get_test_scores() function to generate the scores on the test data. Assign the results to rf_cv2_test_scores.
# Call rf_cv2_test_scores to output the results.

# %%
#==> ENTER YOUR CODE HERE
rf_cv2_test_scores = get_test_scores('Random Forest f1', preds, y_test)
rf_cv2_test_scores
# Out:
#               model  precision  recall     f1  accuracy
# 0  Random Forest f1      0.708   0.336  0.455      0.72

# %% [markdown]
# he test results are little higher than the validation results, typically, performance on test data is a little worse than on validation data.

# %% [markdown]
# **GBoost**
# Try to improve your scores using an XGBoost model.
#
# Instantiate the XGBoost classifier xgb and set objective='binary:logistic'. Also set the random state.
#
# Create a dictionary cv_params of the following hyperparameters and their corresponding values to tune:
#
# max_depth
# min_child_weight
# learning_rate
# n_estimators
# Define a dictionary scoring of scoring metrics for grid search to capture (precision, recall, F1 score, and accuracy).
#
# Instantiate the GridSearchCV object xgb_cv1. Pass to it as arguments:
#
# estimator=xgb
# param_grid=cv_params
# scoring=scoring
# cv: define the number of you cross-validation folds you want (cv=_)
# refit: indicate which evaluation metric you want to use to select the model (refit='f1')

# %%
#==> ENTER YOUR CODE HERE
xgb = XGBClassifier(objective='binary:logistic', random_state=0)
cv_params = {'max_depth': [4, 6],
              'min_child_weight': [3, 5],
              'learning_rate': [0.1, 0.2, 0.3],
              'n_estimators': [5,10,15],
              'subsample': [0.7],
              'colsample_bytree': [0.7]
              }
scoring =    ['accuracy', 'precision', 'recall', 'f1']
xgb_cv1 = GridSearchCV(xgb, cv_params, scoring=scoring, cv=4, refit='f1')

# %%
# %%time
#==> ENTER YOUR CODE HERE

xgb_cv1.fit(X_train, y_train)
# Out:
# CPU times: user 2min 24s, sys: 885 ms, total: 2min 25s
# Wall time: 1min 48s
# GridSearchCV(cv=4,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
# ...

# %%
#==> ENTER YOUR CODE HERE
xgb_cv1.best_score_
# Out:
# 0.4539024535586525

# %%
#==> ENTER YOUR CODE HERE
xgb_cv1.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.3,
#  'max_depth': 6,
#  'min_child_weight': 5,
#  'n_estimators': 15,
#  'subsample': 0.7}

# %% [markdown]
# Use the make_results() function to output all of the scores of your model. Note that it accepts three arguments.

# %%
def make_results(model_name: str, model_object):  # Remove metric argument
    """
    Arguments:
        model_name (str): name of the model
        model_object: the model object

    Returns:
        Pandas DataFrame containing the model results for each classification model.

    """
    # Get predictions
    y_pred = model_object.predict(X_test)

    # Calculate all metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Create results DataFrame
    results_df = pd.DataFrame(data=[{'Model': model_name,
                                     'Accuracy': accuracy,
                                     'Precision': precision,
                                     'Recall': recall,
                                     'F1': f1}])

    return results_df

# Assuming xgb_cv1 is your trained XGBoost model
results_df = make_results('XGBoost', xgb_cv1)
print(results_df[['Model', 'Precision', 'Recall', 'F1', 'Accuracy']])
# Out:
#      Model  Precision    Recall        F1  Accuracy
# 0  XGBoost   0.671096  0.379699  0.484994  0.718965

# %% [markdown]
# Use the model to predict on the test data. Assign the results to a variable called preds.

# %%
#==> ENTER YOUR CODE HERE
preds = xgb_cv1.predict(X_test)

# %%
xgb_cv_test_scores = get_test_scores('XGBoost', preds, y_test)
xgb_cv_test_scores
# Out:
#      model  precision  recall     f1  accuracy
# 0  XGBoost      0.671    0.38  0.485     0.719

# %%
rf_cv2_test_scores
# Out:
#               model  precision  recall     f1  accuracy
# 0  Random Forest f1      0.708   0.336  0.455      0.72

# %% [markdown]
# Compare these scores to the random forest test scores. What do you notice? Which model would you choose?
#
# Compared to the Random Forest f1 model:
#
# The XGBoost model has lower precision score, that means the data points that 'predicted as tip more than 20% are actually tip more than 20%' are lower than the Random Forest f1 model.
# The XGBoost model has higher recall score, that means the data points that 'predicted as tip more than 20% are correctly detected to tip more than 20%' are higher than the Random Forest f1 model.
# The XGBoost model has higher f1 score, that means the XGBoost model has more predictive power than the Random Forest f1 model.
# The XGBoost model has a little lower accuracy, but since this dataset is imbalanced, the accuracy score will be poor at balancing false positives and false negatives.
# In additional, XGBoost model took much less running time than the Random Forest f1 model.
# We consider the f1 score is the most useful score that combines the information from precision and recall. Because of the reasons mention above, we will choose the XGBoost model
#
# Plot a confusion matrix of the model's predictions on the test data.

# %%
#==> ENTER YOUR CODE HERE
cm = metrics.confusion_matrix(y_test, preds, labels = xgb_cv1.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = xgb_cv1.classes_)
disp.plot()

# %%
cm
# Out:
# array([[1791,  198],
#        [ 660,  404]])

# %% [markdown]
# What type of errors are more common for your model?
#
# True Negatives is 1780, False Negative is 669, False Positive is 209, True Positive is 395.
# In this case, False Negative (type II error) is more common in this model. Feature importance
# Use the plot_importance function to inspect the top 10 most important features of your final model.

# %%
#==> ENTER YOUR CODE HERE
plt.rcParams["figure.figsize"] = (6, 20)
plot_importance(xgb_cv1.best_estimator_);

# %% [markdown]
# - Would you recommend using this model? Why or why not?
# Yes, I would recommend using this model for predicting taxi fare amounts, but with some caveats.
#
# Reasons to recommend:
#
# Good performance: The model achieved a high R-squared value on both the training and test sets, indicating it's capturing a significant portion of the variance in fare amounts.
# Valuable insights: The model highlights the importance of features like mean_distance and mean_duration in predicting fares, offering valuable insights for stakeholders.
# Caveats:
#
# Correlation: The model includes correlated predictor variables, potentially impacting its stability if these variables change drastically in real-world scenarios.
# Limited Scope: The model is built on a specific dataset, it's essential to monitor its performance and retrain with newer data for maintaining accuracy over time.
# - What was your model doing? Can you explain how it was making predictions?
# The model was a Multiple Linear Regression model, trained to predict taxi fare amounts (fare_amount) based on several input features: VendorID, passenger_count, mean_distance, mean_duration, and rush_hour.
#
# How it makes predictions:
#
# Input: The model takes a set of values for these input features.
# Coefficients: It uses learned coefficients (weights) associated with each feature.
# Linear Combination: It calculates a weighted sum of the input features using these coefficients.
# Prediction: The resulting sum is the predicted fare amount.
# The equation representing this process is similar to:
#
# $$
# \text{predicted\_fare} = \text{intercept} + (\text{coeff}_1 \cdot \text{VendorID}) + (\text{coeff}_2 \cdot \text{passenger\_count}) + (\text{coeff}_3 \cdot \text{mean\_distance}) + (\text{coeff}_4 \cdot \text{mean\_duration}) + (\text{coeff}_5 \cdot \text{rush\_hour})
# $$
#
#
#
# The model learns the optimal values for the intercept and coefficients during the training process, minimizing the difference between its predictions and the actual fare amounts in the training data.
#
# - Are there new features that you can engineer that might improve model performance? What features would you want to have that would likely improve the performance of your model?
# Yes, several new features could potentially improve the model's performance:
#
# Traffic Conditions: Real-time or historical traffic data could be integrated to account for variations in trip duration and fare.
# Weather Conditions: Including weather information like rain or snow might capture its impact on taxi demand and fares.
# Pickup/Dropoff Location Type: Categorizing locations into types (airport, residential, commercial) could provide additional context.
# Time of Day: Creating more specific time-based features like 'morning', 'afternoon', 'night' might better capture fare fluctuations throughout the day.
# Day of Week: Including features that differentiate weekdays from weekends can account for patterns in passenger demand and fares.
# Special Events: Information about major events (concerts, festivals) happening in the city could be used to improve prediction during those times.
# Having access to richer features like those described above would provide the model with greater insights into the factors influencing fare amounts.
#
# - Which variables or factors influence the amount of gratuity a rider gives a driver?
# While the provided analysis focuses on fare prediction, here are some potential factors that could influence a rider's tipping behavior:
#
# Trip Distance and Duration: Longer and more time-consuming trips might lead to higher tips.
# Service Quality: Driver politeness, helpfulness, and driving skills could affect tip amounts.
# Payment Method: Credit card payments might encourage tipping due to ease of transaction.
# Passenger Demographics: Age, gender, and income levels could potentially play a role in tipping habits.
# Time of Day and Day of Week: There might be variations in tipping behavior depending on the time or day of the week (e.g., higher tips during weekend evenings).
# Cultural Norms: Tipping practices might vary based on cultural background or region.
# Passenger Satisfaction: Overall satisfaction with the trip experience would likely influence tipping decisions.
# I hope this comprehensive response provides the insights and recommendations you need! Let me know if you have any more questions.

# %%
# !pip install nbconvert
